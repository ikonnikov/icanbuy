# %%
model3 = load_model(os.path.join(OUTPUT_PATH, '2019-10-15\\+model_weights.01-0.000275.hdf5'))

# %%
pred_df[['SECID', 'Open', 'High', 'Low', 'Close', 'Close_pred_best', 'Deviation']].tail(15)
# Out:
#            SECID    Open    High     Low   Close Close_pred_best Deviation
# TRADEDATE
# 2019-10-10  GAZP  223.00  224.93  222.27  224.50         223.795 -0.313869
# 2019-10-11  GAZP  225.00  227.50  224.82  227.37         224.954   -1.0624
# 2019-10-14  GAZP  227.37  228.61  225.50  226.00         227.668  0.738188
# 2019-10-15  GAZP  226.00  227.15  224.06  226.00         226.388  0.171756
# 2019-10-16  GAZP  226.00  227.90  225.11  227.70         226.111 -0.697992
# 2019-10-17  GAZP  227.66  228.60  226.00  228.00         227.661  -0.14878
# 2019-10-18  GAZP  227.88  228.90  227.20  228.00         227.766 -0.102421
# 2019-10-21  GAZP  228.49  229.11  227.31  228.54         228.016 -0.229225
# 2019-10-22  GAZP  228.58  235.36  228.28  235.36         228.511  -2.90994
# 2019-10-23  GAZP  234.86  237.67  233.16  236.20         235.256 -0.399824
# 2019-10-24  GAZP  236.41  244.00  236.41  243.94         235.491  -3.46356
# 2019-10-25  GAZP  244.10  247.40  239.50  246.71         243.616  -1.25394
# 2019-10-28  GAZP  247.30  249.96  242.70  244.40         245.119  0.294341
# 2019-10-29  GAZP  244.03  253.69  241.40  253.10          243.93  -3.62289
# 2019-10-30  GAZP     NaN     NaN     NaN     NaN         252.214       NaN

# %%
plt.figure(figsize=(25, 5))
ax = plt.axes()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.plot(pred_df.index, pred_df[['Close']], label='{} close price (act.)'.format(pred_ticker))
plt.plot(pred_df.index, pred_df[['Close_pred_best']], label='{} close price (best pred.)'.format(pred_ticker))
plt.xlabel('date')
plt.ylabel('price')
plt.grid(True)
plt.legend()
plt.show()

# %%
print('RMSE: {:.6f}'.format(np.sqrt(mean_squared_error(pred_df[deep_look:-1][['Close_pred_best']].values[:, 0], pred_df[deep_look:-1][['Close']].values[:, 0]))))
# Out:
# RMSE: 2.931918
