# %%
model3 = load_model(os.path.join(OUTPUT_PATH, '2019-10-15\\+model_weights.01-0.000275.hdf5'))

# %%
pred_df[['SECID', 'Open', 'High', 'Low', 'Close', 'Close_pred_best', 'Deviation, %']].tail(15)
# Out:
#            SECID    Open    High     Low   Close Close_pred_best Deviation, %
# TRADEDATE
# 2019-10-29  GAZP  244.03  253.69  241.40  253.10          243.93     -3.62289
# 2019-10-30  GAZP  252.90  265.26  252.01  261.60         252.214     -3.58784
# 2019-10-31  GAZP  262.25  267.40  257.00  260.00         260.704     0.270855
# 2019-11-01  GAZP  260.10  264.28  256.35  263.79         258.208     -2.11622
# 2019-11-05  GAZP  266.00  267.53  261.31  263.00         261.823    -0.447518
# 2019-11-06  GAZP  263.14  266.98  258.91  266.98         261.997     -1.86654
# 2019-11-07  GAZP  266.01  272.68  264.66  270.74         265.385     -1.97797
# 2019-11-08  GAZP  269.92  270.20  264.45  266.00         269.567      1.34114
# 2019-11-11  GAZP  265.00  265.45  259.80  260.40          263.69      1.26359
# 2019-11-12  GAZP  260.81  264.57  256.13  257.25         259.326     0.806922
# 2019-11-13  GAZP  256.11  257.19  250.79  251.80         257.683      2.33632
# 2019-11-14  GAZP  252.56  253.46  244.80  248.34          251.52      1.28043
# 2019-11-15  GAZP  248.50  250.47  245.00  248.01         248.441     0.173892
# 2019-11-18  GAZP  250.00  250.40  245.62  246.15         248.115     0.798426
# 2019-11-19  GAZP     NaN     NaN     NaN     NaN         246.844          NaN

# %%
plt.figure(figsize=(25, 5))
ax = plt.axes()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.plot(pred_df.index, pred_df[['Close']], label='{} close price (act.)'.format(pred_ticker))
plt.plot(pred_df.index, pred_df[['Close_pred_best']], label='{} close price (best pred.)'.format(pred_ticker))
plt.xlabel('date')
plt.ylabel('price')
plt.grid(True)
plt.legend()
plt.show()

# %%
print('RMSE: {:.6f}'.format(np.sqrt(mean_squared_error(pred_df[deep_look:-1][['Close_pred_best']].values[:, 0], pred_df[deep_look:-1][['Close']].values[:, 0]))))
# Out:
# RMSE: 3.277611
